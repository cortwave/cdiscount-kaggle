# %%
from skimage.io import imread, imshow
from skimage.util import pad
from imgaug import augmenters as iaa
from torchvision import transforms
# %matplotlib inline
import sys
sys.path.append("../src")
import pt_util

# %%
img = imread("../data/images/train/0_0.jpg")
img.shape
# Out:
# (180, 180, 3)

# %%
imshow(img)

# %%
augm = pad(pad_width=((38, 38), (38, 38), (0, 0)), array=img, mode='maximum')
print("shape = ", augm.shape)
imshow(augm)
# Out:
# shape =  (256, 256, 3)

# %%
aug = iaa.Sequential([
    iaa.Crop(px=(0, 50))
])

# %%
imshow(aug.augment_image(augm))

# %%
import numpy as np
import torch
import torchvision
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop([160, 160]),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
to_pil = torchvision.transforms.ToPILImage()
t_aug = transform(img)
to_pil(t_aug)
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F46EFE561D0>

# %%
w, h = transforms.ToPILImage()(img).size
w, h
# Out:
# (180, 180)
