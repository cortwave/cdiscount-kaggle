# %%
import json
import matplotlib.pyplot as plt
from cv2 import imread
import numpy as np
# %matplotlib inline

plt.style.use('ggplot')

# %%
with open('data/cosine_train.json') as data:
    data = [json.loads(s) for s in data.readlines()]

# %%
from itertools import chain
import pandas as pd

flat = pd.DataFrame(list(chain(*data)))

# %%
flat[flat.img_a.str.startswith('100007_')]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>distance</th>
#       <th>img_a</th>
#       <th>img_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>419</th>
#       <td>0.294</td>
#       <td>100007_1</td>
#       <td>100007_2</td>
#     </tr>
#     <tr>
#       <th>420</th>
#       <td>0.159</td>
#       <td>100007_1</td>
#       <td>100007_0</td>
#     </tr>
#     <tr>
#       <th>421</th>
#       <td>0.246</td>
#       <td>100007_1</td>
#       <td>100007_3</td>
#     </tr>
#     <tr>
#       <th>422</th>
#       <td>0.411</td>
#       <td>100007_2</td>
#       <td>100007_0</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>0.180</td>
# ...

# %%
plt.imshow(np.hstack((imread('data/images/100007_0.jpg'),
                      imread('data/images/100007_1.jpg')))
           )

# %%
flat.distance.plot(kind='hist', bins=100)
